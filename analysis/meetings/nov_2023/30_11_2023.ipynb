# %%
import optical_gating_analysis
import matplotlib.pyplot as plt

# %%
og = optical_gating_analysis.BasicOpticalGating()
og.sequence_manager.set_source(r"D:\Data\2012-06-20 13.34.11 vid 2x2 multi phase single plane\brightfield\*tif")
og.sequence_manager.set_reference_sequence(r"D:\Data\2012-06-20 13.34.11 vid 2x2 multi phase single plane\ref_seq.tif")
og.sequence_manager.reference_period = 3.577851226661945105e+01
og.run()
# Out:
# Setting reference sequence from D:\Data\2012-06-20 13.34.11 vid 2x2 multi phase single plane\ref_seq.tif

# %%
plt.figure(figsize = (16,9))
plt.scatter(og.phases[1::], og.delta_phases, s = 5)
plt.show()
