# %%
import optical_gating_analysis as OG
import matplotlib.pyplot as plt
import numpy as np
import j_py_sad_correlation as jps

# %%
data_src = r"D:\Data\both 800fps\brightfield\*tif"

# %%
oog = OG.BasicOpticalGating()
oog.sequence_manager.set_source(data_src)
oog.settings["pi_space"] = False
oog.settings["include_reference_frames"] = True
oog.run()
# Out:
# Setting source to D:\Data\both 800fps\brightfield\*tif
# Getting reference sequence
# Reference period: 306.2209554777414; Reference indices: [111, 422]
# Getting SADs
# Getting phases

# %%
plt.figure(figsize = (16,9))
plt.scatter(oog.phases[1::], oog.delta_phases, s = 5, c = range(len(oog.delta_phases)))
plt.show()

# %%
print(np.where(oog.delta_phases > 15))
# Out:
# (array([], dtype=int64),)

# %%
plt.plot(oog.sads[8200])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(oog.sads[8200])
#
# IndexError: list index out of range

# %%
plt.plot(oog.sads[7827])
plt.plot(oog.sads[7828])
plt.plot(oog.sads[7829])

# %%
plt.plot(np.mean(oog.sads, axis = 0))

# %%
data = OG.SequenceManager.load_tif(r"E:\data\my data\Arrhythmic imaging April 2024\2024-04-05 12.53.59 vid no water\Allied Vision Technologies GS650 0001f61c\*tif")

# %%
plt.figure(figsize = (16,9))
plt.plot(range(1000), np.mean(data, axis = (1,2))[0:1000])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize = (16,9))
# ----> 2 plt.plot(range(1000), np.mean(data, axis = (1,2))[0:1000])
#       3 plt.show()
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize = (16,9))
plt.plot(np.cumsum(oog.delta_phases - 1)[0:2000])
plt.show()
