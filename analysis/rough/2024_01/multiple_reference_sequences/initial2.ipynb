# %%
import optical_gating_analysis as OG
import matplotlib.pyplot as plt
import numpy as np
import j_py_sad_correlation as jps
import tifffile as tf

# %%
data = tf.imread(r"E:\data\my data\January 2024 Arrhythmic\Dosage tests\Caffeine\fish 2\post\early\Allied Vision Technologies GS650 0001f61c.tif")

# %%
sad = []
for i in range(data.shape[0]):
    sad.append(jps.sad_with_references(data[i], data[np.arange(len(data))!=i]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 sad = []
#       2 for i in range(data.shape[0]):
# ----> 3     sad.append(jps.sad_with_references(data[i], data[np.arange(len(data))!=i]))
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (32,32))
plt.imshow(sad, interpolation = "none")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize = (32,32))
# ----> 2 plt.imshow(sad, interpolation = "none")
#
# File c:\Users\kross\anaconda3\envs\optical-gating\lib\site-packages\matplotlib\pyplot.py:2645, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2638 @docstring.copy(Axes.imshow)
#    2639 def imshow(
#    2640         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    (...)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
# ...

# %%
plt.plot(np.diag(sad))
plt.show()

# %%
print(np.min(sad))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(np.min(sad))
#
# File <__array_function__ internals>:200, in amin(*args, **kwargs)
#
# File c:\Users\kross\anaconda3\envs\optical-gating\lib\site-packages\numpy\core\fromnumeric.py:2946, in amin(a, axis, out, keepdims, initial, where)
#    2829 @array_function_dispatch(_amin_dispatcher)
#    2830 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2831          where=np._NoValue):
#    2832     """
#    2833     Return the minimum of an array or minimum along an axis.
#    2834
#    (...)
#    2944     6
#    2945     """
# -> 2946     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2947                           keepdims=keepdims, initial=initial, where=where)
#
# ...

# %%
plt.plot(np.diff(np.argmin(sad, axis = 0)))

# %%
diffs = []
for i in range(1, data.shape[0]):
    diffs.append(np.sum(np.abs(data[i] - data[i-1])))

# %%
plt.figure(figsize = (10,10))
plt.plot(diffs)
