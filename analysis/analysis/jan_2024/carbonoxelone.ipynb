# %%
import optical_gating_analysis as OG
import matplotlib.pyplot as plt
import numpy as np

# %%
data_src = r"E:\data\my data\January 2024 Arrhythmic\caffeine\0.2_4\2024-01-19 19.35.41 vid\Allied Vision Technologies GS650 0001f61c\*tif"
pre = OG.BasicOpticalGating()
pre.sequence_manager.set_source(data_src)
pre.run()

data_src = r"E:\data\my data\January 2024 Arrhythmic\Dosage tests\Carbononxolone\Fish 1\Post\2024-01-18 15.47.08 vid\Allied Vision Technologies GS650 0001f61c\*tif"
post = OG.BasicOpticalGating()
post.sequence_manager.set_source(data_src)
post.run()
# Out:
# Setting source to E:\data\my data\January 2024 Arrhythmic\caffeine\0.2_4\2024-01-19 19.35.41 vid\Allied Vision Technologies GS650 0001f61c\*tif
# Getting reference sequence
# Getting SADs
# Getting phases
# Setting source to E:\data\my data\January 2024 Arrhythmic\Dosage tests\Carbononxolone\Fish 1\Post\2024-01-18 15.47.08 vid\Allied Vision Technologies GS650 0001f61c\*tif
# Getting reference sequence
# Getting SADs
# Getting phases

# %%
plt.scatter(np.arange(pre.delta_phases.shape[0])[0:300], pre.delta_phases[0:300], label="pre")
plt.show()
plt.scatter(np.arange(post.delta_phases.shape[0]), post.delta_phases, label="post")
plt.show()

plt.scatter(pre.phases[1::], pre.delta_phases)
plt.show()
plt.scatter(post.phases[1::], post.delta_phases)
plt.show()

# %%
print(np.mean(pre.delta_phases))
print(np.mean(post.delta_phases))
# Out:
# 0.0985320099287103
# 0.09611152208818517
