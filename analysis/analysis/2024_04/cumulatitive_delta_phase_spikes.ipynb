# %%
import optical_gating_analysis as OG
import matplotlib.pyplot as plt
import numpy as np
import j_py_sad_correlation as jps

# %%
oog = OG.BasicOpticalGating()#.default()
oog.sequence_manager.set_source(r"D:\Data\2012-06-20 13.34.11 vid 2x2 multi phase single plane\brightfield\*tif")
oog.settings["pi_space"] = False
oog.settings["include_reference_frames"] = True
oog.run()
# Out:
# Setting source to D:\Data\both 800fps\brightfield\*tif
# Getting reference sequence
# Reference period: 306.2806208454796; Reference indices: [111, 434]
# Getting SADs
# Getting phases

# %%
plt.plot(np.cumsum(oog.delta_phases)[100:120])

# %%
plt.plot(np.cumsum(oog.delta_phases - 1)[100:120])

# %%
plt.plot(oog.sads[114])
plt.plot(oog.sads[115])
plt.plot(oog.sads[116])
