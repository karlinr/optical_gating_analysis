# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.linspace(0, 100, 100) % (2 * np.pi)

plt.plot(xs)
plt.show()
plt.plot(np.diff(xs))
plt.show()
plt.plot(np.unwrap(xs))
plt.show()
plt.plot(np.diff(np.unwrap(xs)))
